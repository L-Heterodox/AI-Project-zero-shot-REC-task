# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# 假设有一个名为image的图像对象
# 假设result["bboxes"]是包含框坐标的二维列表

# 创建一个图像和子图
fig, ax = plt.subplots(1)
image_path='./train2014/COCO_train2014_000000002964.jpg'
image = Image.open(image_path)
ax.imshow(image)

# # 为每个框添加矩形
# for box in result["bboxes"]:
#     rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=1, edgecolor='r', facecolor='none')
#     ax.add_patch(rect)
#box = [93.6318359375, 24.8797607421875, 251.88241577148438, 359.6169128417969]
box = [146.62879943847656, 15.826324462890625, 93.11953735351562, 341.7581787109375]
# rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=1, edgecolor='r', facecolor='none')
rect = patches.Rectangle((box[0], box[3]), box[2]-box[0], box[1]-box[3], linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)

# 显示图像和框
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# 假设有一个名为image的图像对象
# 假设result["bboxes"]是包含框坐标的二维列表

# 创建一个图像和子图
fig, ax = plt.subplots(1)
image_path='./train2014/COCO_train2014_000000002964.jpg'
image = Image.open(image_path)
ax.imshow(image)

bboxes =  [[13.211872100830078, 77.47528839111328, 107.44210815429688, 103.58635711669922], [237.6209716796875, 14.310211181640625, 324.91571044921875, 354.12115478515625], [146.62879943847656, 15.826324462890625, 239.7483367919922, 357.5845031738281], [321.505859375, 11.073379516601562, 410.36663818359375, 373.4586181640625], [400.0433654785156, 4.5640106201171875, 496.7183532714844, 364.36248779296875], [52.85099792480469, 5.76165771484375, 556.8759155273438, 345.38861083984375]]
# 为每个框添加矩形
for box in bboxes:
    rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=1, edgecolor='b', facecolor='none')
    ax.add_patch(rect)
# box = [93.6318359375, 24.8797607421875, 251.88241577148438, 359.6169128417969]
# box = [25.768203735351562, 122.08058166503906, 147.99139404296875, 217.36827087402344]
# rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=1, edgecolor='r', facecolor='none')
# rect = patches.Rectangle((box[0], box[3]), box[2]-box[0], box[1]-box[3], linewidth=1, edgecolor='b', facecolor='none')
ax.add_patch(rect)

# 显示图像和框
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# 假设有一个名为image的图像对象
# 假设result["bboxes"]是包含框坐标的二维列表

# 创建一个图像和子图
fig, ax = plt.subplots(1)
image_path='./train2014/COCO_train2014_000000002964.jpg'
image = Image.open(image_path)
ax.imshow(image)

# # # 为每个框添加矩形
# # for box in result["bboxes"]:
# #     rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=1, edgecolor='r', facecolor='none')
# #     ax.add_patch(rect)
# #box = [93.6318359375, 24.8797607421875, 251.88241577148438, 359.6169128417969]
# box = [25.768203735351562, 122.08058166503906, 147.99139404296875, 217.36827087402344]
# # rect = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], linewidth=1, edgecolor='r', facecolor='none')
# rect = patches.Rectangle((box[0], box[3]), box[2]-box[0], box[1]-box[3], linewidth=1, edgecolor='r', facecolor='none')
# ax.add_patch(rect)

# 显示图像和框
plt.show()
